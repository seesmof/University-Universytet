# %%
import random
import pandas as pd

rows = 10
data = [
    {
        "age": random.randint(30, 70),
        "steps": random.randint(1000, 5000),
    }
    for row in range(rows)
]
data = pd.DataFrame(data)
data
# Out:
#    age  steps
# 0   63   2208
# 1   31   2095
# 2   68   1274
# 3   60   2389
# 4   62   3779
# 5   55   3301
# 6   37   1501
# 7   52   3502
# 8   69   3451
# 9   55   3549
